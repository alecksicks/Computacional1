# %%
import pandas as pd
import matplotlib.pylab as plt
from datetime import datetime
import numpy as np

# %%
df = pd.read_csv("FortPoint.csv", names = ("Date Time", "Water Level", "Sigma", "O", "F", "R", "L", "Quality"), header = 0)
df.head()
# Out:
#           Date Time  Water Level  Sigma  O  F  R  L Quality
# 0  2016-03-27 00:00        0.273  0.003  0  0  0  0       v
# 1  2016-03-27 00:06        0.272  0.003  0  0  0  0       v
# 2  2016-03-27 00:12        0.258  0.002  0  0  0  0       v
# 3  2016-03-27 00:18        0.269  0.003  0  0  0  0       v
# 4  2016-03-27 00:24        0.283  0.002  0  0  0  0       v

# %%
df['Date'] = pd.to_datetime(df["Date Time"], format = '%Y %m %d %H:%M:')

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Date Time      0
# Water Level    0
# Sigma          0
# O              0
# F              0
# R              0
# L              0
# Quality        0
# Date           0
# dtype: int64

# %%
x= df['Date']
y= df['Water Level']

tides = plt.plot(df[u'Date'], df[u'Water Level'], 'g', label ="Altura")
plt.xlim(pd.Timestamp('2016-03-27 00:00:00'), pd.Timestamp('2016-04-26 23:59:00')) 
plt.ylabel('Altura de marea [m]')
plt.xlabel('Fecha')
plt.title('Nivel de Marea en Fort Point, New Hampshire, desde Marzo 2016 hasta Abril 2016')
plt.grid(True)

plt.plot(x,y)
plt.show()
