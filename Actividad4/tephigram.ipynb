# %%
import pandas as pd
import matplotlib.pyplot as mplt
import pylab as plt
import os.path
import tephi as tph

# %%
dew_point = pd.read_csv("presDWPT.csv", names=["Presión", "DWPT"])
dry_bulb = pd.read_csv("presTEMP.csv", names=["Presión", "TEMP"])
tpg = tph.Tephigram()
tpg.plot(dew_point)
tpg.plot(dry_bulb)
plt.show()
